# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from utils.plots import plot_raw_data

# %%
df_DS1 = pd.read_csv('data/DS1.csv')
print("df_DS1_len", len(df_DS1))
# Out:
# df_DS1_len 1807

# %%
df_DS1.describe()
# Out:
#        Level Sensor-1  Level Sensor-2  Level Sensor-3   Fluid Flow
# count     1807.000000     1807.000000     1807.000000  1807.000000
# mean        86.227702       86.771062       57.125938   376.858903
# std         12.335185       11.716011        9.960105    79.089796
# min         37.175832       44.386132       28.903188   248.068303
# 25%         76.694582       76.646622       48.948269   300.780602
# 50%         87.315418       87.748687       57.054397   375.125781
# 75%         96.659594       97.230504       65.814368   449.639135
# max        107.488882      106.610232       78.300330   502.637461

# %%
plot_raw_data(df_DS1)
